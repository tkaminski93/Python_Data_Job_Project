# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  
import seaborn as sns

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_PL = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'Poland')].copy()

# %%
df_DA_PL = df_DA_PL.dropna(subset=['salary_year_avg'])

df_DA_PL_exploded = df_DA_PL.explode('job_skills')

df_DA_PL_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#       salary_year_avg  job_skills
# 1490          43200.0        gdpr
# 1490          43200.0         sap
# 1490          43200.0  powerpoint
# 1490          43200.0       excel
# 6567          56700.0           r

# %%
df_DA_skills = df_DA_PL_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_PL)

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

skill_percent = 5

df_DA_skills_high_demand = df_DA_skills[df_DA_skills['skill_percent'] > skill_percent]

df_DA_skills_high_demand
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                  26      102500.00      60.465116
# excel                16       74250.00      37.209302
# python               15      102500.00      34.883721
# tableau              13      111175.00      30.232558
# gcp                  10      106837.50      23.255814
# power bi              8       82350.00      18.604651
# spark                 8      111175.00      18.604651
# looker                6      111175.00      13.953488
# windows               5      111175.00      11.627907
# airflow               5      111175.00      11.627907
# git                   4      102500.00       9.302326
# powerpoint            4       74958.75       9.302326
# vba                   4       57100.00       9.302326
# sap                   4       66858.75       9.302326
# r                     4       84337.50       9.302326
# azure                 3       89100.00       6.976744

# %%
from adjustText import adjust_text

# %%
from matplotlib.ticker import PercentFormatter

# %%
df_DA_skills_high_demand.plot(kind='scatter', x='skill_percent', y='median_salary')
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analyst in the US')

# Get current axes, set limits, and format axes
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))  # Example formatting y-axis
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}
for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():
        if key in technology_dict:  # if key already exists in technology_dict, add value to existing value
            technology_dict[key] += value
        else:                       # if key does not exist in technology_dict, add key and value
            technology_dict[key] = value

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['spreadsheet',
#   'cognos',
#   'datarobot',
#   'splunk',
#   'word',
#   'esquisse',
#   'microstrategy',
#   'dax',
#   'visio',
#   'spss',
#   'powerbi',
#   'tableau',
#   'msaccess',
#   'looker',
#   'power bi',
#   'sap',
#   'ssrs',
#   'excel',
#   'sheets',
#   'sharepoint',
#   'qlik',
#   'ssis',
#   'outlook',
#   'powerpoint',
#   'ms access',
#   'sas',
#   'nuix',
#   'alteryx'],
#  'programming': ['assembly',
#   'erlang',
#   'bash',
#   't-sql',
#   'elixir',
#   'solidity',
#   'css',
#   'ocaml',
#   'julia',
#   'r',
#   'html',
#   'nosql',
#   'shell',
#   'visual basic',
#   'sql',
#   'visualbasic',
#   'c',
#   'powershell',
#   'apl',
#   'ruby',
#   'fortran',
#   'vb.net',
#   'java',
#   'haskell',
#   'lua',
#   'c#',
#   'dart',
#   'cobol',
#   'swift',
#   'python',
#   'vba',
#   'sass',
#   'clojure',
#   'golang',
#   'mongodb',
#   'groovy',
#   'scala',
#   'objective-c',
#   'php',
#   'kotlin',
#   'pascal',
#   'mongo',
#   'f#',
#   'c++',
#   'go',
#   'matlab',
#   'perl',
#   'delphi',
#   'sas',
#   'crystal',
#   'lisp',
#   'rust',
#   'no-sql',
#   'typescript',
#   'javascript'],
#  'cloud': ['vmware',
#   'digitalocean',
#   'watson',
#   'openstack',
#   'ibm cloud',
#   'azure',
#   'aurora',
#   'ovh',
#   'databricks',
#   'firebase',
#   'bigquery',
#   'oracle',
#   'aws',
#   'redshift',
#   'heroku',
#   'linode',
#   'colocation',
#   'snowflake',
#   'gcp'],
#  'libraries': ['gtx',
#   'hadoop',
#   'chainer',
#   'numpy',
#   'scikit-learn',
#   'capacitor',
#   'ggplot2',
#   'shogun',
#   'pyspark',
#   'ionic',
#   'kafka',
#   'seaborn',
#   'mlr',
#   'rshiny',
#   'pandas',
#   'theano',
#   'gdpr',
#   'tensorflow',
#   'cordova',
#   'spring',
#   'react',
#   'spark',
#   'flutter',
#   'pytorch',
#   'mxnet',
#   'huggingface',
#   'tidyr',
#   'selenium',
#   'jupyter',
#   'xamarin',
#   'keras',
#   'plotly',
#   'qt',
#   'matplotlib',
#   'opencv',
#   'electron',
#   'hugging face',
#   'dlib',
#   'tidyverse',
#   'graphql',
#   'airflow',
#   'mlpack',
#   'dplyr',
#   'nltk'],
#  'other': ['atlassian',
#   'docker',
#   'chef',
#   'terraform',
#   'gitlab',
#   'bitbucket',
#   'codecommit',
#   'github',
#   'pulumi',
#   'homebrew',
#   'unreal',
#   'kubernetes',
#   'npm',
#   'terminal',
#   'svn',
#   'ansible',
#   'yarn',
#   'flow',
#   'unity',
#   'puppet',
#   'git',
#   'jenkins'],
#  'databases': ['elasticsearch',
#   'redis',
#   'firebase',
#   'couchbase',
#   'firestore',
#   'db2',
#   'mysql',
#   'couchdb',
#   'sqlserver',
#   'neo4j',
#   'postgresql',
#   'mariadb',
#   'cassandra',
#   'mongodb',
#   'sqlite',
#   'sql server',
#   'dynamodb'],
#  'os': ['redhat',
#   'ubuntu',
#   'centos',
#   'macos',
#   'arch',
#   'wsl',
#   'kali',
#   'windows',
#   'debian',
#   'suse',
#   'unix',
#   'fedora',
#   'linux'],
#  'async': ['monday.com',
#   'clickup',
#   'jira',
#   'trello',
#   'wimi',
#   'airtable',
#   'wrike',
#   'workfront',
#   'dingtalk',
#   'smartsheet',
#   'notion',
#   'planner',
#   'confluence',
#   'asana',
#   'microsoft lists'],
#  'webframeworks': ['react.js',
#   'jquery',
#   'asp.net core',
#   'symfony',
#   'angular.js',
#   'asp.net',
#   'node.js',
#   'drupal',
#   'angular',
#   'nuxt.js',
#   'next.js',
#   'deno',
#   'asp.netcore',
#   'vue',
#   'blazor',
#   'ruby',
#   'ember.js',
#   'express',
#   'django',
#   'phoenix',
#   'laravel',
#   'fastapi',
#   'flask',
#   'ruby on rails',
#   'rubyon rails',
#   'fastify',
#   'vue.js',
#   'gatsby',
#   'node',
#   'svelte',
#   'play framework'],
#  'sync': ['slack',
#   'google chat',
#   'ringcentral',
#   'symphony',
#   'zoom',
#   'unify',
#   'twilio',
#   'microsoft teams',
#   'webex',
#   'wire',
#   'mattermost',
#   'rocketchat']}

# %%
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology           skills
# 0   analyst_tools      spreadsheet
# 0   analyst_tools           cognos
# 0   analyst_tools        datarobot
# 0   analyst_tools           splunk
# 0   analyst_tools             word
# ..            ...              ...
# 9            sync  microsoft teams
# 9            sync            webex
# 9            sync             wire
# 9            sync       mattermost
# 9            sync       rocketchat
#
# [256 rows x 2 columns]

# %%
df_DA_skills_tech = df_DA_skills.merge(df_technology, left_on='job_skills', right_on='skills')

df_DA_skills_tech
# Out:
#     skill_count  median_salary  skill_percent     technology        skills
# 0            26      102500.00      60.465116    programming           sql
# 1            16       74250.00      37.209302  analyst_tools         excel
# 2            15      102500.00      34.883721    programming        python
# 3            13      111175.00      30.232558  analyst_tools       tableau
# 4            10      106837.50      23.255814          cloud           gcp
# 5             8       82350.00      18.604651  analyst_tools      power bi
# 6             8      111175.00      18.604651      libraries         spark
# 7             6      111175.00      13.953488  analyst_tools        looker
# 8             5      111175.00      11.627907             os       windows
# 9             5      111175.00      11.627907      libraries       airflow
# 10            4      102500.00       9.302326          other           git
# 11            4       74958.75       9.302326  analyst_tools    powerpoint
# 12            4       57100.00       9.302326    programming           vba
# 13            4       66858.75       9.302326  analyst_tools           sap
# 14            4       84337.50       9.302326    programming             r
# 15            3       89100.00       6.976744          cloud         azure
# 16            2       77187.50       4.651163      libraries          gdpr
# 17            2      133750.00       4.651163      libraries        hadoop
# 18            2      131750.00       4.651163    programming         nosql
# 19            2       77600.00       4.651163      libraries         numpy
# 20            2      111175.00       4.651163  analyst_tools           sas
# 21            2      111175.00       4.651163    programming           sas
# 22            2       77600.00       4.651163      libraries        pandas
# 23            2       77757.00       4.651163      libraries       pyspark
# 24            2      106837.50       4.651163          other          flow
# 25            1       98500.00       2.325581    programming           c++
# 26            1       89100.00       2.325581      databases    sql server
# 27            1       89100.00       2.325581  analyst_tools          ssrs
# 28            1      111175.00       2.325581          cloud      bigquery
# 29            1       89100.00       2.325581           sync      symphony
# 30            1      111175.00       2.325581          cloud     snowflake
# 31            1       56700.00       2.325581      libraries     tidyverse
# 32            1       98500.00       2.325581             os          unix
# 33            1       75600.00       2.325581          other       jenkins
# 34            1       72000.00       2.325581  analyst_tools           dax
# 35            1      111175.00       2.325581          async          jira
# 36            1       89100.00       2.325581  analyst_tools    sharepoint
# 37            1      102500.00       2.325581      libraries  scikit-learn
# 38            1       98500.00       2.325581      libraries    matplotlib
# 39            1       98500.00       2.325581    programming          rust
# 40            1      111175.00       2.325581  analyst_tools          qlik
# 41            1      165000.00       2.325581             os         linux
# 42            1      165000.00       2.325581          cloud           aws
# 43            1       89100.00       2.325581  analyst_tools       outlook
# 44            1       89100.00       2.325581          cloud        oracle
# 45            1      165000.00       2.325581    programming         mongo
# 46            1       72900.00       2.325581  analyst_tools          word

# %%
df_DA_skills_tech_high_demand = df_DA_skills_tech[df_DA_skills_tech['skill_percent'] > skill_percent]

# %%
sns.scatterplot(
    data=df_DA_skills_tech_high_demand,
    x='skill_percent',
    y='median_salary',
    hue='technology'
)

sns.despine()
sns.set_theme(style='ticks')

# Prepare texts for adjustText
texts = []
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], txt))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in the US')
plt.legend(title='Technology')

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot 
plt.tight_layout()
plt.show()
