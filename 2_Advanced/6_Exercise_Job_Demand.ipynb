# %%
# Import Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_pl = df[df['job_country'] == 'Poland'].copy()

# %%
df_pl
# Out:
#                   job_title_short  \
# 18                   Data Analyst
# 108                 Data Engineer
# 125                 Data Engineer
# 136                Data Scientist
# 351             Software Engineer
# ...                           ...
# 785549             Data Scientist
# 785592        Senior Data Analyst
# 785650          Software Engineer
# 785669  Machine Learning Engineer
# 785702           Business Analyst
#
#                                                 job_title     job_location  \
# 18                                           Data Analyst   Warsaw, Poland
# 108                    Chapter Lead Data Engineers Poland  Wrocław, Poland
# 125                                         Data Engineer   Kraków, Poland
# 136                   Mid/ Senior Data Scientist with NLP         Anywhere
# 351                       Data Platform Software Engineer   Warsaw, Poland
# ...                                                   ...              ...
# ...

# %%
df_pl['job_posted_month'] = df_pl['job_posted_date'].dt.strftime('%B')

df_pl
# Out:
#                   job_title_short  \
# 18                   Data Analyst
# 108                 Data Engineer
# 125                 Data Engineer
# 136                Data Scientist
# 351             Software Engineer
# ...                           ...
# 785549             Data Scientist
# 785592        Senior Data Analyst
# 785650          Software Engineer
# 785669  Machine Learning Engineer
# 785702           Business Analyst
#
#                                                 job_title     job_location  \
# 18                                           Data Analyst   Warsaw, Poland
# 108                    Chapter Lead Data Engineers Poland  Wrocław, Poland
# 125                                         Data Engineer   Kraków, Poland
# 136                   Mid/ Senior Data Scientist with NLP         Anywhere
# 351                       Data Platform Software Engineer   Warsaw, Poland
# ...                                                   ...              ...
# ...

# %%
df_pl_pivot = df_pl.pivot_table(index='job_posted_month',columns='job_title_short', aggfunc='size')

# %%
df_pl_pivot.reset_index(inplace=True)
df_pl_pivot['month_no'] = pd.to_datetime(df_pl_pivot['job_posted_month'], format='%B').dt.month
df_pl_pivot.sort_values('month_no', inplace=True)
df_pl_pivot.set_index('job_posted_month', inplace=True)
df_pl_pivot.drop(columns='month_no', inplace=True)

# %%
df_pl_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        182              53           505
# February                       157              33           395
# March                          112              55           336
# April                          148              42           283
# May                             80              21           245
# June                            92              16           209
# July                           119              36           258
# August                         101              56           310
# September                       53              14           142
# October                         65              28           174
# November                        46              19           167
# December                        49              20           148
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_pl_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df_pl['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()

# %%
df_pl_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data Jobs in Poland')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()
